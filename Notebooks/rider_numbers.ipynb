# %%
# Plot of passengers per head of population

import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("seaborn-poster")
plt.style.use("ggplot")
# Out:
# /tmp/ipykernel_260319/1138106128.py:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-poster")

# %%
df_old = pd.read_excel("../Data/bus01_hist.ods", sheet_name="BUS01b_hist", header=6)
df_old = df_old[df_old.Year.str.contains("/") ]#& (df_old["Bus Service Type"] == "Local bus services")]
df_old = df_old.pivot_table("Passenger Journeys, per head of population", ["Year"], "Region")
df_old.tail()
# Out:
# Region   East Midlands  East of England  England  England outside London  \
# Year
# 2000/01             52               34       78                      59
# 2001/02             51               33       78                      58
# 2002/03             50               32       80                      58
# 2003/04             50               31       82                      56
# 2004/05             47               30       82                      55
#
# Region   English metropolitan areas  English non-metropolitan areas  \
# Year
# 2000/01                         110                              42
# 2001/02                         110                              40
# 2002/03                         108                              40
# 2003/04                         106                              39
# 2004/05                         103                              38
#
# Region   Great Britain  London  North East  North West  Scotland  South East  \
# Year
# 2000/01             77     186          98          75        90          37
# 2001/02             78     194          95          76        92          36
# 2002/03             79     207          96          75        93          36
# 2003/04             81     229          89          76        94          36
# 2004/05             81     242          85          74        94          36
#
# Region   South West  Wales  West Midlands  Yorkshire and the Humber
# Year
# 2000/01          38     41             87                        80
# 2001/02          37     37             86                        78
# 2002/03          37     39             83                        78
# 2003/04          37     39             79                        75
# 2004/05          37     40             77                        71

# %%
df_new = pd.read_excel("../Data/bus01.ods", sheet_name="BUS01b", header=7, index_col="Year")
df_new.head()
# Out:
#          North East  North West  Yorkshire and the Humber  East Midlands  \
# Year
# 2004/05   81.095731   64.267814                 69.137007      46.694768
# 2005/06   79.312803   64.406099                 69.773764      46.559600
# 2006/07   80.826271   64.964175                 70.284490      46.191096
# 2007/08   79.602519   67.483699                 71.196648      48.719349
# 2008/09   81.408623   67.158995                 72.185886      48.537499
#
#          West Midlands  East of England      London  South East  South West  \
# Year
# 2004/05      76.128267        30.363731  242.496499   34.809362   33.823143
# 2005/06      74.881995        30.164688  250.177916   35.201974   33.597433
# 2006/07      75.092393        32.691974  262.359557   37.448280   36.650695
# 2007/08      75.488179        33.455035  280.805813   38.237377   37.907360
# 2008/09      75.374905        33.945575  285.222152   38.918967   39.371153
#
#          English metropolitan areas  English non-metropolitan areas  \
# Year
# 2004/05                   95.253736                       37.036855
# 2005/06                   94.802260                       36.969728
# 2006/07                   94.586695                       38.852860
# 2007/08                   95.524600                       40.061740
# 2008/09                   95.515816                       40.724859
#
#            England   Scotland      Wales  Great Britain  \
# Year
# 2004/05  80.213486  90.330660  41.575054      79.134582
# 2005/06  81.293203  91.071019  40.446294      80.077904
# 2006/07  84.330037  92.706590  39.785287      82.806812
# 2007/08  88.169186  94.249880  41.675081      86.350134
# 2008/09  89.479444  92.953468  42.906419      87.433486
#
#          England outside London  \
# Year
# 2004/05               52.005977
# 2005/06               51.821554
# 2006/07               53.139827
# 2007/08               54.245510
# 2008/09               54.728416
#
#                                                    Revised
# Year
# 2004/05                                                [z]
# 2005/06                                                [z]
# 2006/07                                                [z]
# 2007/08                                                [z]
# 2008/09  [r] Yorkshire and the Humber, England, Great B...

# %%
df = pd.concat([df_old, df_new])

# %%
df[["London", "Scotland", "England outside London", "Wales", "English metropolitan areas"]].plot()
# Out:
# <AxesSubplot: xlabel='Year'>
