# %%
import pandas as pd

# %%
df = pd.read_excel("../Data/bus01_hist.ods", sheet_name="BUS01a_hist", header=6)

# %%
df.head()
# Out:
#    Year         Region    Bus Service Type  Passenger Journeys, millions Notes
# 0  1950  Great Britain  Local bus services                         12734   [z]
# 1  1950  Great Britain  Other bus services                           260   [z]
# 2  1955  Great Britain  Local bus services                         13225   [z]
# 3  1955  Great Britain  Other bus services                           337   [z]
# 4  1956  Great Britain  Local bus services                         13059   [z]

# %%
df["Region"].unique()
# Out:
# array(['Great Britain', 'English metropolitan areas', 'London',
#        'Scotland', 'England', 'England outside London',
#        'English non-metropolitan areas', 'Wales', 'East Midlands',
#        'East of England', 'North East', 'North West', 'South East',
#        'South West', 'West Midlands', 'Yorkshire and the Humber'],
#       dtype=object)

# %%
df[df.Region == "London"].plot(x="Year", y="Passenger Journeys, millions")
# Out:
# <AxesSubplot: xlabel='Year'>

# %%
df[df.Region == "West Midlands"].plot(x="Year", y="Passenger Journeys, millions")
# Out:
# <AxesSubplot: xlabel='Year'>
